# %%
import pandas as pd
import numpy as np

# %%
dat = pd.read_csv("data22.csv")

# %%
dataAsList = []
for i in range(len(dat)):
    list_data = list(dat.iloc[i])
    dataAsList.append(list_data)
pd.DataFrame(dataAsList, columns = ["movieName", "movieYear", "songName", "songSinger", "songMusic", "songLyricist","songLyrics"])
# Out:
#                          0     1                                  2  \
# 0                     1920  2008               Tujhe Main Pyar Karu
# 1                     1920  2008                Aise Jalta Hai Jiya
# 2                     1920  2008              Vaada Tumse Hai Vaada
# 3     1920 - Evil Returns   2012                       Uska Hi Bana
# 4     1920 - Evil Returns   2012                      Jaavedaan Hai
# ...                    ...   ...                                ...
# 1353         Welcome Back   2015              Tutti Bole Wedding Di
# 1354            Woh 7 Din   1983         Mere Dil Se Dillagi Na Kar
# 1355            Woh 7 Din   1983              Pyaar Kiya Nahi Jaata
# 1356            Woh 7 Din   1983  Anari Ka Khelna Khel Ka Satyanash
# 1357            Woh 7 Din   1983           Kangana Oye Hoye Kangana
#
#                                     3                    4             5  \
# 0                        Kailash Kher           Adnan Sami        Sameer
# ...

# %%
data.describe()
# Out:
#          movieYear
# count  1358.000000
# mean   1997.820324
# std      17.496734
# min    1938.000000
# 25%    1985.000000
# 50%    2004.000000
# 75%    2013.000000
# max    2018.000000

# %%
data.head()
# Out:
#               movieName   movieYear               songName     songSinger  \
# 0                  1920        2008   Tujhe Main Pyar Karu   Kailash Kher
# 1                  1920        2008    Aise Jalta Hai Jiya    Asha Bhosle
# 2                  1920        2008  Vaada Tumse Hai Vaada  Pandit Jasraj
# 3  1920 - Evil Returns         2012           Uska Hi Bana   Arijit Singh
# 4  1920 - Evil Returns         2012          Jaavedaan Hai        Kay Kay
#
#          songMusic  songLyricist  \
# 0       Adnan Sami        Sameer
# 1       Adnan Sami        Sameer
# 2       Adnan Sami        Sameer
# 3  Chirantan Bhatt   Manoj Yadav
# 4  Chirantan Bhatt  Shakeel Azmi
#
#                                           songLyrics
# 0  Tujhe main pyar karoon\nAur itna pyar karoon\n...
# 1  Aaja re, aaja re, aaja re, aa..\nAaja re, aaja...
# 2  Vaada tumse hai vaada\nHo vaada tumse hai vaad...
# 3  Meri qismat ke har ek panne pe\nMere jeete jee...
# ...

# %%
data.columns
# Out:
# Index(['movieName', ' movieYear', ' songName', ' songSinger', ' songMusic',
#        ' songLyricist', ' songLyrics'],
#       dtype='object')

# %%
data["songLyrics"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'songLyrics'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-1665819e6a05> in <module>
# ----> 1 data["songLyrics"]
#
# ...
