# %%
import pandas as pd
import numpy as np
import nltk
import gensim 
from gensim.models.phrases import Phrases, Phraser
import re
# from wordcloud import WordCloud
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from collections import defaultdict
from collections import Counter 
from gensim.models import Word2Vec
# from googletrans import Translator

# %%
data=pd.read_csv("data")

# %%
singerName = ''
mySingerDictionary = {}
singers = list(data.songSinger)

for singer in singers:
    
    try:
        for individualSinger in (singer.split(",")):
            singerName = ''
            s = individualSinger.split(" ")
            if(s[0] == ''):
                length = len(s)
                if(len(s)== 3):
                    singerName = s[1] + ' '+ s[2]
                else:
                    singerName = s[1]
            else:
                l = len(s)
                for i in range(l):
                    if i == l-1:
                        singerName = singerName + s[i]
                    else:
                        singerName = singerName+s[i]+' '  
                        
            mySingerDictionary[singerName] = True
            
    except:
        print("Found error in processing: ")
        print(singer)
# Out:
# Found error in processing:
# nan
# Found error in processing:
# nan
# Found error in processing:
# nan
# Found error in processing:
# nan
# Found error in processing:
# nan
# Found error in processing:
# nan
# Found error in processing:
# nan
# Found error in processing:
# nan

# %%
temp = {}
mySingerDictionary
# Out:
# {'Badshah': True,
#  'Shalmali Kholgade': True,
#  'Gurdeep Mehendi': True,
#  'Samira Koppikar': True,
#  'Shreya Ghoshal': True,
#  'Brijesh Shandilya': True,
#  'Dino James': True,
#  'Kailash Kher': True,
#  'Swaroop Khan': True,
#  'Guru Randhawa': True,
#  'Tochi Raina': True,
#  'Divya Kumar': True,
#  'DIVINE': True,
#  'Aavrutti': True,
#  'D’Evil': True,
#  'Shah Rule': True,
#  'Dave East': True,
#  'Sharib Sabri': True,
#  'Mohit Chauhan': True,
#  'Nitin Mukesh': True,
#  'Jubin Nautiyal': True,
#  'Saloni Thakkar': True,
#  'Amit Mishra': True,
#  'Akasa Singh': True,
#  'Amartya': True,
#  'Dev Arijit': True,
#  'GD 47': True,
#  'Sukriti Kakar': True,
#  'Tanishk Bagchi': True,
#  'Yasser Desai': True,
#  'Asees Kaur': True,
#  'Nabeel Shaukat': True,
#  'Ranjit Bawa': True,
#  'Mannat Noor': True,
#  'Arijit Singh': True,
#  'Neha Kakkar': True,
#  'Yash Narvekar': True,
#  'Danish Sabri': True,
#  'Sukhwinder Singh': True,
#  'Shadab Faridi': True,
#  'Mika Singh': True,
#  'Farhad Samji': True,
#  'Vishal Dadlani': True,
#  'Sohail Sen': True,
#  'Altamash Faridi': True,
#  'Jyotica Tangri': True,
#  'Sona Mohapatra': True,
#  'Asha Bhosle': True,
#  'Vishal Mishra': True,
#  'Sunidhi Chauhan': True,
#  'Jyoti Nooran': True,
#  'Priya Saraiya': True,
#  'Jonita Gandhi': True,
#  'Sachin-Jigar': True,
#  'Nikhita Gandhi': True,
#  'Benny Dayal': True,
#  'Darshan Raval': True,
#  'Arjun Kanungo': True,
#  'Lisa Mishra': True,
#  'Shashwat Singh': True,
#  'Antara Mitra': True,
#  'Nikhil D’Souza': True,
#  'Baani Sandhu': True,
#  'Singga': True,
#  'Sidhu Moose Wala': True,
#  'Arko': True,
#  'Aakanksha Sharma': True,
#  'Shilpa Rao': True,
#  'Alyssa Mendonsa': True,
#  'Raghuvir Yadav': True,
#  'Shankar Mahadevan': True,
#  'Vikram Khajuria': True,
#  'Ali': True,
#  'Vikram Montrose': True,
#  'Ankit Tiwari': True,
#  'Deepali Sathe': True,
#  'Bhoomi Trivedi': True,
#  'Dev Negi': True,
#  'Sachet Tandon': True,
#  'Parampara Thakur': True,
#  'Hansraj Raghuwanshi': True,
#  'Ash King': True,
#  'Monali Thakur': True,
#  'KK': True,
#  'Nakash Aziz': True,
#  'Manish Tipu': True,
#  'Geet Sagar': True,
#  'Sreerama Chandra': True,
#  'Amitabh Bhattacharya': True,
#  'Tushar Joshi': True,
#  'Jass Zaildar': True,
#  'Khushboo Grewal': True,
#  'Palak Muchhal': True,
#  'Meet Bros': True,
#  'Amit Gupta': True,
#  'Raja Hasan': True,
#  'Romy': True,
#  'Anand Bhaskar': True,
#  'Abhijeet Srivastava': True,
#  'Vibha Saraf': True,
#  'Ranu Mondal': True,
#  'Himesh Reshammiya': True,
#  'Aaryan Tiwari': True,
#  'Harshdeep Kaur': True,
#  'Alamgir Khan': True,
#  'Anusha Mani': True,
#  'Navraj Hans': True,
#  'Dhvani Bhanushali': True,
#  'Tulsi Kumar': True,
#  'B Praak': True,
#  'Amir Khan': True,
#  'Protijyoti Ghosh': True,
#  'Daniel': True,
#  'Surabhi Dashputra': True,
#  'Arjunna Harjaie': True,
#  'Arun Dev Yadav': True,
#  'Navv Inder': True,
#  'Raja Kumari': True,
#  'Ravi Mishra': True,
#  'Neeti Mohan': True,
#  'Yo Yo Honey Singh': True,
#  'Ashok Mastie': True,
#  'Pravesh Mallick': True,
#  'Asim Azhar': True,
#  'Zenab': True,
#  'Jabar Abbas': True,
#  'Shiraz Uppal': True,
#  'Raktima Mukherjee': True,
#  'Mustafa Zahid': True,
#  'Mustahsan Khan': True,
#  'Atif Aslam': True,
#  'Ali Sethi': True,
#  'Zeb Bangash': True,
#  'Neeraj Shridhar': True,
#  'Enbee': True,
#  'Rico': True,
#  'Payal Dev': True,
#  'Abhijeet': True,
#  'Chandra Dixit': True,
#  'Jasbir Jassi': True,
#  'Diljit Dosanjh': True,
#  'Guru Bhullar': True,
#  'Akash D': True,
#  'Arohi Mhatre': True,
#  'Aditi Prabhudesai': True,
#  'Pragati Joshi': True,
#  'Maithili Panse': True,
#  'Sonal Naik': True,
#  'Rucha Soman': True,
#  'Deepti Rege': True,
#  'Deepanshi Nagar': True,
#  'Ann Fernandes': True,
#  'Dr': True,
#  'Shivika Rajesh': True,
#  'Riddhi Sampat': True,
#  'Kinjal Shah': True,
#  'Umesh Joshi': True,
#  'Vijay Dhuri': True,
#  'Mandar Pilvalkar': True,
#  'Vivek Naik': True,
#  'Rahul Chitnis': True,
#  'Saurabh Wakhare': True,
#  'Janardan Dhatrak': True,
#  'Gaurav Medatwal': True,
#  'Chaitanya Shinde': True,
#  'Abhishek Jhawar': True,
#  'Nimish Shah': True,
#  'Yash Kapoor': True,
#  'Mayukh Pareek': True,
#  'Hrithik Roshan': True,
#  'Prem Areni': True,
#  'Chaitally Parmar': True,
#  'Udit Narayan': True,
#  'Mame Khan': True,
#  'R Venkatraman': True,
#  'Amit Trivedi': True,
#  'Armaan Malik': True,
#  'Slow Cheetah': True,
#  'Dee MC': True,
#  'Kaam Bhaari': True,
#  'Spitfire': True,
#  'Priyani Vani': True,
#  'Toshi': True,
#  'Kanika Kapoor': True,
#  'Ikka': True,
#  'Tony Kakkar': True,
#  'Shail Hada': True,
#  'Rutvik Talashilkar': True,
#  'Aanandi Joshi': True,
#  'Shreyas Puranik': True,
#  'Adarsh Shinde': True,
#  'Raj Ranjodh': True,
#  'Shipra Goyal': True,
#  'Akhil Sachdeva': True,
#  'Neha Bhasin': True,
#  'Kamaal Khan': True,
#  'Deane Sequeira': True,
#  'Sanam Puri': True,
#  'Shekhar Ravjiani': True,
#  'Kishore Kumar': True,
#  'Marianne': True,
#  'Garry Sandhu': True,
#  'Mellow D': True,
#  'Shashi Suman': True,
#  'Yash Wadali': True,
#  'Parmish Verma': True,
#  'Goldy': True,
#  'Prabh Gill': True,
#  'Kamal Heer': True,
#  'Aditya Narayan': True,
#  'Shirley Setia': True,
#  'Abhijit Vaghani': True,
#  'Salim Merchant': True,
#  'Yo': True,
#  'Javed Ali': True,
#  'Vaishali Mhade': True,
#  'Mohit Pathak': True,
#  'Kavita Seth': True,
#  'Shriram Iyer': True,
#  'K Mohan': True,
#  'Sameer Khan': True,
#  'Sonu Nigam': True,
#  'Amitabh Bachchan': True,
#  'Clinton Cerejo': True,
#  'Jizzy': True,
#  'Salman Khan': True,
#  'Shaan': True,
#  'Subhro': True,
#  'Parineeti Chopra': True,
#  'Yuvraj Hans': True,
#  'Karan Sehmbi': True,
#  'Akhil': True,
#  'Sunanda Sharma': True,
#  'Ranveer Singh': True,
#  'Naezy': True,
#  'D’EVIL': True,
#  'Nexus': True,
#  'Rahul Raahi': True,
#  'Emiway': True,
#  'D-cypher': True,
#  'BeatRAW': True,
#  'Big Sid': True,
#  'Shashwat Sachdev': True,
#  'Vivek Hariharan': True,
#  'Ena Marley': True,
#  'Ananya Bhat': True,
#  'Vijay Prakash': True,
#  'Santhosh Venki': True,
#  'Sachin Basrur': True,
#  'Puneeth Rudranag': True,
#  'Mohan': True,
#  'H.': True,
#  'Vijay Aurs': True,
#  'Ravi Basrur': True,
#  'Goldi': True,
#  'Rahat Fateh Ali Khan': True,
#  'Kumar Sanu': True,
#  'Shashaa Tirupati': True,
#  'Rahat': True,
#  'Shaadab Faridi': True,
#  'Kunal Ganjawala': True,
#  'Abhay Jodhpurkar': True,
#  'Bilal Saeed': True,
#  'Pratibha Baghel': True,
#  'Singhsta': True,
#  'Simar Kaur': True,
#  'Fazilpuria': True,
#  'Raftaar': True,
#  'Raghav Sachar': True,
#  'Shafqat': True,
#  'Ayushmann Khurrana': True,
#  'Jordan': True,
#  'Shafqat Amanat Ali': True,
#  'Nawazuddin Siddiqui': True,
#  'Mannan Shaah': True,
#  'Aastha Gill': True,
#  'Shahid Mallya': True,
#  'Akanksha Bhandari': True,
#  'KK-singer': True,
#  'Shadaab Faridi': True,
#  'Vishal Bhardwaj': True,
#  'Rekha Bhardwaj': True,
#  'Ronkini Gupta': True,
#  'Papon': True,
#  'Gurnam Bhullar': True,
#  'Ammy Virk': True,
#  'Neetu Bhalla': True,
#  'Kamal Khan': True,
#  'Divya Bhatt': True,
#  'Harshit Saxena': True,
#  'Prakriti Kakar': True,
#  'Palomi Ghosh': True,
#  'Ronit Sarkar': True,
#  'Meenal Jain': True,
#  'Yashita Sharma': True,
#  'Yashika Sikka': True,
#  'Rani Kaur': True,
#  'Anita Gandharva': True,
#  'Meghna Mishra': True,
#  'Vaishnavi Mishra': True,
#  'Devender Pal Singh': True,
#  'Bhanu': True,
#  'Jazim Sharma': True,
#  'Vijay Yamla': True,
#  'Suhas Sawant': True,
#  'Mast Ali': True,
#  'Sikander Kahlon': True,
#  'Amit Sharma': True,
#  'Babul Supriyo': True,
#  'Sathyaprakash': True,
#  'Andrea Jeremiah': True,
#  'Shivangi Bhayana': True,
#  'Mudassar Aziz': True,
#  'Jassi Gill': True,
#  'Sonakshi Sinha': True,
#  'Sachin Sanghvi': True,
#  'Jigar Saraiya': True,
#  'Jordi Patel': True,
#  'Disha Sharma': True,
#  'Akash Ojha': True,
#  'Rekha': True,
#  'Dharmendra': True,
#  'Shatrughan Sinha': True,
#  'Hardy Sandhu': True,
#  'Deep Kahlon': True,
#  'Revant Shergill': True,
#  'Iulia Vantur': True,
#  'Vineet Singh': True,
#  'Akshay Kumar': True,
#  'Karan Singh Arora': True,
#  'Girik Aman': True,
#  'Wajid': True,
#  'Gurinder': True,
#  'Altamash': True,
#  'Nettle': True,
#  'Gurinder Seagal': True,
#  'Ali Zafar': True,
#  'Aima Baig': True,
#  'Ajay Gogavale': True,
#  'Atul Gogavale': True,
#  'Daler Mehndi': True,
#  'Shehnaz Akhtar': True,
#  'Hemant Brijwasi': True,
#  'Sahil Akhtar': True,
#  'Ehsaan Noorani': True,
#  'Ranbir Kapoor': True,
#  'Supriya Pathak': True,
#  'Poorvi Koutish': True,
#  'Veera Saxena': True,
#  'Shivai Vyas': True,
#  'Ashwin Kulkarni': True,
#  'Aaroh Velankar': True,
#  'Anurag Sharma': True,
#  'Himanshu Shirlekar': True,
#  'Shubham Shirule': True,
#  'Sunny MR': True,
#  'Deep Money': True,
#  'Keerthi Sagathia': True,
#  'Babu Haabi': True,
#  'Aditi': True,
#  'Nikita Ahuja': True,
#  'Lulia Vantur': True,
#  'Sharvi Yadav': True,
#  'Jasleen Royal': True,
#  'Amrinder Gill': True,
#  'Hiral Brahmbhatt': True,
#  'Rishi Kapoor': True,
#  'Bir Singh': True,
#  'Gurshabad': True,
#  'Haricharan': True,
#  'Gajendra Verma': True,
#  'Ishan Mitra': True,
#  'Mahalakshmi Iyer': True,
#  'BIG Dhillon': True,
#  'Jatinder Singh': True,
#  'Siddharth Basrur': True,
#  'Shruti Pathak': True,
#  'Parry G': True,
#  'Gippy Grewal': True,
#  'Kulwinder Billa': True,
#  'Rajvir Jawanda': True,
#  'Sharan Maan': True,
#  'Pawni Pandey': True,
#  'Happy Raikoti': True,
#  'Jaz Dhami': True,
#  'Rahul Jain': True,
#  'Amrita Singh': True,
#  'Khusboo Grewal': True,
#  'Sajid': True,
#  'Manj Musik': True,
#  'Rochak Kohli': True,
#  'Zack Knight': True,
#  'Ishers': True,
#  'Raxstar': True,
#  'Akshay Verma': True,
#  'Mohammed Irfan Ali': True,
#  'Tanishq Gaur': True,
#  'Tanishq Kaur': True,
#  'Arnab Dutta': True,
#  'Piyush Mehroliyaa': True,
#  'Mohammed Irfan': True,
#  'Shree D': True,
#  'Mohammed Rafi': True,
#  'Anirudh Ravichander': True,
#  'Lil Golu': True,
#  'Swati Sharma': True,
#  'Mamta Sharma': True,
#  'Richa Sharma': True,
#  'Shivam Pathak': True,
#  'Mujtaba': True,
#  'Kunal Pandit': True,
#  'Farhan Sabri': True,
#  'Kavita Krishnamurthy': True,
#  'Krishna Beura': True,
#  'Asit Tripathy': True,
#  'Nooran Sisters': True,
#  'Raghu Dixit': True,
#  'Veet Baljit': True,
#  'Tarannum Malik': True,
#  'Roach Killa': True,
#  'Anu Malik': True,
#  'Simran': True,
#  'Dilpreet Dhillon': True,
#  'Sharry Mann': True,
#  'Ninja': True,
#  'Rajnigandha Shekhawat': True,
#  'Master': True,
#  'Ritu Pathak': True,
#  'Abhishek Nailwal': True,
#  'Sameer Uddin': True,
#  'Sidharth Malhotra': True,
#  'Nusrat Fateh Ali Khan': True,
#  'Neeraj Arya’s Kabir Café': True,
#  'Vidya Vox': True,
#  'ARJUN': True,
#  'Vickey Prasad': True,
#  'Arpita Mukherjee': True,
#  'Apeksha Dandekar': True,
#  'Amaal Mallik': True,
#  'Mohd. Irfan': True,
#  'Cuca Roseta': True,
#  'Pardeep Singh Sran': True,
#  'Pritam': True,
#  'Aman Trikha': True,
#  'Shefali Alvares': True,
#  'Satinder Sartaaj': True,
#  'Dee Ajayi': True,
#  'Sukhbir': True,
#  'Mehak Malhotra': True,
#  'Millind Gaba': True,
#  'Gupz Sehra': True,
#  'Mehtab Virk': True,
#  'Amrit Maan': True,
#  'Asses Kaur': True,
#  'Renesa Baadchi': True,
#  'Pranaay': True,
#  'Nandini Deb': True,
#  'Rahul Pandey': True,
#  'Siddharth Mahadevan': True,
#  'Ashwin': True,
#  'Aroh': True,
#  'Sunny': True,
#  'Taz – Stereo Nation': True,
#  'Sanjeev Chimmalgi': True,
#  'Ramya Behara': True,
#  'Karan Aujla': True,
#  'Jass Manak': True,
#  'Gagan Kokri': True,
#  'Ambili': True,
#  'Sonia Sharma': True,
#  'KD': True,
#  'Juggy D': True,
#  'Shivi': True,
#  'AR Rahman': True,
#  'Pardeep': True,
#  'Taniskaa Sanghvi': True,
#  'SUKHBIR': True,
#  'Shraddha Kapoor': True,
#  'Veronica Mehta': True,
#  'Anushka Shahaney': True,
#  'Ami Mishra': True,
#  'Rahul Mishra': True,
#  'Farhan Saeed': True,
#  'Roshan Prince': True,
#  'Sanah Moidutty': True,
#  'Dominique Cerejo': True,
#  'Nimrat Khaira': True,
#  'Gurpreet Maan': True,
#  'Khan Saab': True,
#  'Karamjit Anmol': True,
#  'Tarsem Jassar': True,
#  'Kulbir Jhinjer': True,
#  'Mankirat Pannu': True,
#  'Aditi Singh Sharma': True,
#  'Shilpi Paul': True,
#  'Anushka Sharma': True,
#  'Amber Vashisht': True,
#  'Alia Bhatt': True,
#  'Mansheel Gujral': True,
#  'Gurjazz': True,
#  'Jazzy B': True,
#  'Jasmine Sandlas': True,
#  'Bappi Lahiri': True,
#  'Anuradha Paudwal': True,
#  'Ameen Sayani': True,
#  'Jassie Gill': True,
#  'Babbal Rai': True,
#  'O.S. Arun': True,
#  'Gulzar': True,
#  'Murtuza Mustafa': True,
#  'Qadir Mustafa': True,
#  'Nindy Kaur': True,
#  'Roshan Rathod': True,
#  'Ram Sampath': True,
#  'Karsan Sagathia': True,
#  'Hardeep Grewal': True,
#  'Sarwar Khan': True,
#  'Sartaz': True,
#  'Chinmayi Sripada': True,
#  'Akbar Sami': True,
#  'Priyanka Chopra': True,
#  'John Abraham': True,
#  'Neuman Pinto': True,
#  'Bohemia': True,
#  'Shibani Sur': True,
#  'Swati Sharrma': True,
#  'Zora Randhawa': True,
#  'Fateh Doe': True,
#  'Rupali': True,
#  'Farhan NTF': True,
#  'Gandharv Sachdev': True,
#  'Momina Mustehsan': True,
#  'DJ Bravo': True,
#  'Harshi Mad': True,
#  'Jagjit Singh': True,
#  'Farhan Akhtar': True,
#  'Digvijay Singh Pariyar': True,
#  'Mohit Chuahan': True,
#  'Megha Dalton': True,
#  'Anugrah': True,
#  'Caralisa Monteiro': True,
#  'Sophie Choudry': True,
#  'Malkit Singh': True,
#  'Sonu Sood': True,
#  'Mithoon': True,
#  'Salim-Sulaiman': True,
#  'Shraddha Sharma': True,
#  'Kaushiki Chakraborty': True,
#  'Sain Zahoor': True,
#  'Akhtar Chinnal': True,
#  'Shuchismita Das': True,
#  'Hriday Gattani': True,
#  'Ananya Nanda': True,
#  'Adithyan': True,
#  'Barkat Jamal Fakir Troupe': True,
#  'Zoe Viccaji': True,
#  'Shahab Hussain': True,
#  'Ahad Raza Mir': True,
#  'Shuja Haider': True,
#  'Sahir Ali Bagga': True,
#  'Natasha Baig': True,
#  'Fareed Ayaz': True,
#  'Abu': True,
#  'Ali Hamza': True,
#  'Strings': True,
#  'Humera Arshad': True,
#  'Rachel Viccaji': True,
#  'Natasha Khan': True,
#  'Attaullah Esakhelvi': True,
#  'Sanwal Esakhelvi': True,
#  'Nahid Afrin': True,
#  'Aanya': True,
#  'Prateek Kuhad': True,
#  'Amar Arshi': True,
#  'Tanishka Sanghvi': True,
#  'Vayu': True,
#  'Sumedha Karmahe': True,
#  'Kartik Dhiman': True,
#  'Sakina Khan': True,
#  'Tarranum': True,
#  'Gurlej Akhtar': True,
#  'ARKO': True,
#  'Bela Shende': True,
#  'Mohd Irfan': True,
#  'Shivranjani Singh': True,
#  'Soniya Sharma': True,
#  'Sanjeev Rathod': True,
#  'Darshan Rathod': True,
#  'Sonu Kakkar': True,
#  'Abhijeet Sawant': True,
#  'Yaseer Desai': True,
#  'Awaaz': True,
#  'Kaater': True,
#  '6 Pack Band': True,
#  'Ishita': True,
#  'Shrey Singhal': True,
#  'Akriti Kakar': True,
#  'Thomson Andrews': True,
#  'Keshia Braganza': True,
#  'Gwan Dias': True,
#  'Ryan Dias': True,
#  'Bhanu Pratap': True,
#  'Miss Pooja': True,
#  'Kuwar Virk': True,
#  'Akira (singer)': True,
#  'Hrishikesh Chury': True,
#  'Anmol Malik': True,
#  'Earl Edgar': True,
#  'Sharib-Toshi': True,
#  'Zorawar': True,
#  'Alfaaz': True,
#  'J.Hind': True,
#  'Gurlez Akhtar': True,
#  'Monty Waris': True,
#  'JP Randhawa': True,
#  'G Ranjha': True,
#  'Penny': True,
#  'Harf Cheema': True,
#  'Yaad': True,
#  'Happy Raikoti. Tarranum Malik': True,
#  'Kapil Sharma': True,
#  'Jenny Johal': True,
#  'Arun Daga': True,
#  'Meet Bros Anjjan': True,
#  'Arjun Kapoor': True,
#  'Amruta Fadnavis': True,
#  'Mayuri Patwardhan': True,
#  'Bombay Rockers': True,
#  'Harbhajan Mann': True,
#  'Manoj Tiwari': True,
#  'Vipin Patwa': True,
#  'Muhfaad': True,
#  'Deep Kalsi': True,
#  'Kappie': True,
#  'Suzanne D’Mello': True,
#  'Natasha Tejura': True,
#  'Nandini Srikar': True,
#  'Deepak Rathore': True,
#  'Vijay Narain': True,
#  'Kalyani Nair': True,
#  'Meet': True,
#  'Falak Shabir': True,
#  'Gagan Baderiya': True,
#  'Prashant Pillai': True,
#  'Loco Ink': True,
#  'G Khan': True,
#  'Afsana Khan': True,
#  'Kaur B': True,
#  'GARRY SANDHU': True,
#  'Inder Kaur': True,
#  'Anushka Manchanda': True,
#  'Meet Bors': True,
#  'Master Saleem': True,
#  'Tripat': True,
#  'Ali Azmat': True,
#  'Saugat Upadhaya': True,
#  'Aditya Trivedi': True,
#  'Shabab Sabri': True,
#  'Aishwarya Majmudar': True,
#  'Jankee': True,
#  'Sultana Nooran': True,
#  'Mehak Suri': True,
#  'Aishwarya Bhandari': True,
#  'Shahdab Faridi': True,
#  'Pandit': True,
#  'Prithvi Gandharva': True,
#  'Kanika Joshi': True,
#  'Rashi Raagga': True,
#  'Geetikka Manjrekar': True,
#  'Mujtaba Aziz Naza': True,
#  'Rachel Varghese': True,
#  'Saba Azad': True,
#  'Siddhart Basrur': True,
#  'Nikhil Paul George': True,
#  'Swanand Kirkire': True,
#  'Vipin Anneja': True,
#  'Shraddha Pandit': True,
#  'Nilofer Wani': True,
#  'Dr. Zeus': True,
#  'Rahul Vaidya': True,
#  'Sunil Kamath': True,
#  'MM Manasi': True,
#  'Devi': True,
#  'Alka Yagnik': True,
#  'Haripriya': True,
#  'Lucky Ali': True,
#  'Alma Ferovic': True,
#  'Arjun Chandy': True,
#  'Rasika Shekhar': True,
#  'Siddharth Basrurm': True,
#  'Digvijay': True,
#  'Raman Mahadevan': True,
#  'Qaran': True,
#  'Labh Janjua': True,
#  'Manjeet Singh': True,
#  'Sasha': True,
#  'Arpita Chakraborty': True,
#  'Asrar (Syed Asrar Shah)': True,
#  'Geeta Jhala': True,
#  'Feat.': True,
#  'Rani': True,
#  'Siddhant Madhav': True,
#  'Chinmayi': True,
#  'Suraj Jagan': True,
#  'Rituraj Mohanty': True,
#  'Janusz Kruciński': True,
#  'Gajendra Phogat': True,
#  'Adnan Sami': True,
#  'Rimi Nique': True,
#  'Varun Dhawan': True,
#  'D Soldierz': True,
#  'Madhav Krishna': True,
#  'Sapna Pathak': True,
#  'Sukirti Kakkar': True,
#  'Love Juneja': True,
#  'Deane Sequiera': True,
#  'NS Chauhan': True,
#  'Dilbagh Singh': True,
#  'Suman Sridhar': True,
#  'Aishwarya Nigam': True,
#  'Paroma Dasgupta': True,
#  'Teflon': True,
#  'Imaad Shah': True,
#  'Anupam Roy': True,
#  'Saleema Jawwad': True,
#  'Renuka Gaur': True,
#  'Mili Nair': True,
#  'Mahesh Bhatt': True,
#  'Ved': True,
#  'Ambresh': True,
#  'Ashish': True,
#  'Uzair Jaswal': True,
#  'Hard Kaur': True,
#  'Indeep Bakshi': True,
#  'Soni B': True,
#  'Rajveer Singh': True,
#  'Dipanshu Pandit': True,
#  'Sadhana Sargam': True,
#  'Malini Awasthi': True,
#  'Rahul Ram': True,
#  'A. Sivamani': True,
#  'Arya': True,
#  'Shweta Subram': True,
#  'Javed Bashir': True,
#  'Bharka Swaroop Saxena': True,
#  'Bhaven Dhanak': True,
#  'Saim Bhatt': True,
#  'Prakriti Kakkar': True,
#  'Anupam Amod': True,
#  'Imran Ali': True,
#  'Naved Jafar': True,
#  'Shruti Haasan': True,
#  'IMRAN Khan': True,
#  'Talia Bentson': True,
#  'Arya Acharya': True,
#  'Akull': True,
#  'MellowD': True,
#  'Gulraj Singh': True,
#  'Smita': True,
#  'Vidhi': True,
#  'Priya Andrews': True,
#  'Javed Jaffrey': True,
#  'Nihira Joshi': True,
#  'Roopkumar Rathod': True,
#  'Prajakta Shukre': True,
#  'Vikrant Bhartiya': True,
#  'Kshitij Tarey': True,
#  'Voctronica': True,
#  'SANAM': True,
#  'Brodha V': True,
#  'Suresh Wadkar': True,
#  'Mouli Dave': True,
#  'Resmi Sateesh': True,
#  'SurjRDB': True,
#  'JessieK': True,
#  'Vishal-Shekhar': True,
#  'Shahrukh Khan': True,
#  'Ravindra Upadhyay': True,
#  'Miraya Varma': True,
#  'Amrit Maghera': True,
#  'Mathias Duplessy': True,
#  'Mukhtiyar Ali': True,
#  'Nitu Choudhary': True,
#  'Mofd. Irfan': True,
#  'Niharika Sinha': True,
#  'Dr. Palash Sen': True,
#  'Shweta Pandit': True,
#  'Raghav Mathur': True,
#  'Tanvi Shah': True,
#  'Lata Mangeshkar': True,
#  'Adnan Dhool': True,
#  'Ustad Rashid Khan': True,
#  'Usha Uthup': True,
#  'Prashant Vadhyar': True,
#  'Rajiv Sundaresan': True,
#  'Sunaina Sarkar': True,
#  'Santokh Singh': True,
#  'Piyush Kapoor': True,
#  'Shubhangi Tiwari': True,
#  'Piyush Mishra': True,
#  'Sanchita Bhattacharya': True,
#  'Anweshaa': True,
#  'Subhash Ghai': True,
#  'Parth Bhalerao': True,
#  'Anish': True,
#  'Rituraj': True,
#  'Rasika': True,
#  'Sneha Khanwalkar': True,
#  'Gayatri Ganjawala': True,
#  'Puja Bhalla': True,
#  'Jaspreet Jasz': True,
#  'Roshni Baptist': True,
#  'Rafaqat': True,
#  'Kunal Avanti': True,
#  'Fariha Parvaiz': True,
#  'Suchi': True,
#  'Alam Lohar': True,
#  'IshQ Bector': True,
#  'Shekhar Suman': True,
#  'Adhyayan Suman': True,
#  'Anirudh Bhola': True,
#  'Sukanya Ghosh': True,
#  'Khurram Iqbal': True,
#  'Arunima Bhattacharya': True,
#  'Zebunnisa Bangash': True,
#  'Kash': True,
#  'Krissy': True,
#  'Suvi Suresh': True,
#  'Nupur Pant': True,
#  'Ujjayinee': True,
#  'Marianne D’Cruz': True,
#  'Jamal Akbar': True,
#  'Shivam Mahadevan': True,
#  'Anish Sharman': True,
#  'Osman Mir': True,
#  'Aditi Paul': True,
#  'Anand': True,
#  'Teesha Nigam': True,
#  'Bonnie Chakraborty': True,
#  'Kalpana Patowary': True,
#  'Nitesh Kadam': True,
#  'Ali Aslam': True,
#  'Alisha Chinai': True,
#  'Zubeen Garg': True,
#  'Rajesh Roshan': True,
#  'Bob': True,
#  'Sanjay Misra': True,
#  'Abhijeet Bhattacharya': True,
#  'Sujeet Shetty': True,
#  'Amitosh Nagpal': True,
#  'Sanjeev-Darshan': True,
#  'Wajhi Farooki': True,
#  'Munawwar Masoom': True,
#  'Loy Mendonsa': True,
#  'Sahir': True,
#  'Smokey': True,
#  'Enkore': True,
#  'Natalie': True,
#  'Gopi Sunder': True,
#  'Hamsika Iyer': True,
#  'Sricharan Kasturirangan': True,
#  'S. P. Balasubrahmanyam': True,
#  'Arif Lohar': True,
#  'Rashid Ali': True,
#  'Madhushree': True,
#  'Vaishali Samant': True,
#  'Aanchal Sethi': True,
#  'Kmmc': True,
#  'Rabbi Shergill': True,
#  'Jaswinder Singh': True,
#  'Pooja AV': True,
#  'Sanchita': True,
#  'Sasheh Aagha': True,
#  'S.': True,
#  'Anand Tiwari': True,
#  'Kunal Khemu': True,
#  'Raj': True,
#  'DK': True,
#  'Bornalee Deuri': True,
#  'Sonal Chauhan': True,
#  'Soham': True,
#  'Shubh Mukherjee': True,
#  'Amit Kumar': True,
#  'Sudesh Bhosle': True,
#  'Anil Kapoor': True,
#  'Padmanabh Gaikwad': True,
#  'Bruno Carvalo': True,
#  'Santosh': True,
#  'Aftab Sabri': True,
#  'Hashim Sabri': True,
#  'Harshit Chauhan': True,
#  'Nadeem Khan': True,
#  'Amjad Bagadba': True,
#  'Shantanu Moitra': True,
#  'Remo Fernandes': True,
#  'Chaitra Ambadipudi': True,
#  'Shadab Sabri': True,
#  'MM Kreem': True,
#  'Najim Arshad': True,
#  'Master Salim': True,
#  'Prem Dehati': True,
#  'Ranjit Barot': True,
#  'Chandrakala Singh': True,
#  'Yashraj Kapil': True,
#  'Rajdeep Chatterjee': True,
#  'Inderpreet Singh': True,
#  'Muazzam': True,
#  'Rizwan': True,
#  'Ajay Devgn': True,
#  'Vikas Bhalla': True,
#  'Bhavya Pandit': True,
#  'Shakthisree Gopalan': True,
#  'A. R. Rahman': True,
#  'Bianca Gomes': True,
#  'Neelambari Kirkire': True,
#  'Shazneen Arethna': True,
#  'The Doorbeen': True,
#  'Shreya Sharma': True,
#  'Nisha Mascarenhas': True,
#  'Nazia Hassan': True,
#  'Nikhil': True,
#  'Jeet Gannguli': True,
#  'K.K.': True,
#  'Unoosha': True,
#  'Rushk': True,
#  'Riteish Deshmukh': True,
#  'Raga Boyz': True,
#  'Malathi Sharma': True,
#  'Abhishek Bachchan': True,
#  'Imran Aziz Mian': True,
#  'Masuma Anwar': True,
#  'Urmila Dhangar': True,
#  'Rana Mazumder': True,
#  'Aishwariya Nigam': True,
#  'Anand-Milind': True,
#  'Sarosh Sami': True,
#  'Paroma': True,
#  'Sandeep Patil': True,
#  'Ravi': True,
#  'Khayyam': True,
#  'Amrita Kak': True,
#  'Shahab Sabri': True,
#  'Nikhil Dsouza': True,
#  'Kk': True,
#  'Dr Zeus': True,
#  'Sneha Khanwalker': True,
#  'Durga': True,
#  'Rasika D. Rani': True,
#  'Vedesh Sookoo': True,
#  'Rajneesh Shyamoo': True,
#  'Munna': True,
#  'Altamush Faridi': True,
#  'Keerti Sagathia': True,
#  'Aditi Rao Hydari': True,
#  'Sanam Marvi': True,
#  'Hadiqa Kiani': True,
#  'Himmat Sandhu': True,
#  'Harpi Gill': True,
#  'Jordan Sandhu': True,
#  'Hardeep Singh': True,
#  'Rameez Khalid': True,
#  'Sahara UK': True,
#  'Ali Tariq': True,
#  'Jimmy Khan': True,
#  'Sajjan Adeeb': True,
#  'Maninder Buttar': True,
#  'Veekay': True,
#  'Feroz Khan': True,
#  'Raman Romana': True,
#  'Sudesh Kumari': True,
#  'Puneet Dixit': True,
#  'Esha Gaur': True,
#  'Babbu Maan': True,
#  'Goldy Desi Crew': True,
#  'Sanjith Hegde': True,
#  'Jaani': True,
#  'Shubham Singh': True,
#  'Guri': True,
#  'FEJO': True,
#  'Romi': True,
#  'Arun': True,
#  'Aarsh Benipal': True,
#  'Ripul Sharma': True,
#  'Karthik': True,
#  'Roop Kumar Rathod': True,
#  'Sanjeev Thomas': True,
#  'Timmy': True,
#  'Kalyani Menon': True,
#  'Alphons Joseph': True,
#  'Naresh Iyer': True,
#  'Leon D’Souza': True,
#  'Blaaze': True,
#  'Yashita Yashpal': True,
#  'Priya Patidar': True,
#  'Toshi Sabri': True,
#  'Akram Sabri': True,
#  'Nitin Malik': True,
#  'Himanshu Joshi': True,
#  'Haniya': True,
#  'Imogen Heap': True,
#  ...}

# %%
singerGender = {}

for singer in mySingerDictionary.keys():
    singerGender[singer] = 'm'
    # wait for my input for the female or male name
    # store it in a dictionary
    gender = input("Enter gender of " + singer + " ")
    singerGender[singer] = gender
    print()
    temp = singerGender
# Out:
# Enter gender of  m
#
# Enter gender of Shalmali Kholgade f
#
# Enter gender of Gurdeep Mehendi m
#
# Enter gender of Dino James m
#
# Enter gender of Brijesh Shandilya m
#
# Enter gender of Aavrutti f
#
# Enter gender of D’Evil m
#
# Enter gender of Shah Rule m
#
# Enter gender of Dave East m
#
# Enter gender of Jubin Nautiyal m
#
# Enter gender of Saloni Thakkar f
#
# Enter gender of Akasa Singh f
#
# Enter gender of Amartya f
#
# Enter gender of Dev Arijit m
#
# Enter gender of GD 47 m
#
# Enter gender of Yasser Desai m
#
# Enter gender of Asees Kaur f
#
# Enter gender of Yash Narvekar m
#
# Enter gender of Shreya Ghoshal f
#
# Enter gender of Shadab Faridi m
#
# Enter gender of Farhad Samji m
#
# Enter gender of Altamash Faridi m
#
# Enter gender of Jyotica Tangri f
#
# Enter gender of Vishal Mishra m
#
# Enter gender of Jyoti Nooran f
#
# Enter gender of Priya Saraiya f
#
# Enter gender of Jonita Gandhi f
#
# Enter gender of Sachin-Jigar m
#
# Enter gender of Nikhita Gandhi f
#
# Enter gender of Benny Dayal m
#
# Enter gender of Darshan Raval m
#
# Enter gender of Lisa Mishra f
#
# Enter gender of Antara Mitra f
#
# Enter gender of Nikhil D’Souza m
#
# Enter gender of Shilpa Rao f
#
# Enter gender of Alyssa Mendonsa f
#
# Enter gender of Shankar Mahadevan m
#
# Enter gender of Vikram Khajuria m
#
# Enter gender of Ali m
#
# Enter gender of Vikram Montrose m
#
# Enter gender of Deepali Sathe f
#
# Enter gender of Bhoomi Trivedi f
#
# Enter gender of Parampara Thakur f
#
# Enter gender of Monali Thakur f
#
# Enter gender of Manish Tipu m
#
# Enter gender of Geet Sagar m
#
# Enter gender of Sreerama Chandra m
#
# Enter gender of Amitabh Bhattacharya m
#
# Enter gender of Dev Negi m
#
# Enter gender of Amit Mishra m
#
# Enter gender of Khushboo Grewal f
#
# Enter gender of Palak Muchhal f
#
# Enter gender of Meet Bros m
#
# Enter gender of Nakash Aziz m
#
# Enter gender of Romy m
#
# Enter gender of Anand Bhaskar m
#
# Enter gender of Abhijeet Srivastava m
#
# Enter gender of Vibha Saraf f
#
# Enter gender of Himesh Reshammiya m
#
# Enter gender of Harshdeep Kaur m
#
# Enter gender of Alamgir Khan m
#
# Enter gender of Anusha Mani f
#
# Enter gender of Dhvani Bhanushali f
#
# Enter gender of Tulsi Kumar m
#
# Enter gender of B Praak m
#
# Enter gender of Protijyoti Ghosh f
#
# Enter gender of Daniel m
#
# Enter gender of Arjunna Harjaie m
#
# Enter gender of Raja Kumari m
#
# Enter gender of Ravi Mishra m
#
# Enter gender of Neeti Mohan m
#
# Enter gender of Ashok Mastie m
#
# Enter gender of Pravesh Mallick m
#
# Enter gender of Zenab m
#
# Enter gender of Jabar Abbas m
#
# Enter gender of Shiraz Uppal m
#
# Enter gender of Raktima Mukherjee f
#
# Enter gender of Mustahsan Khan m
#
# Enter gender of Zeb Bangash f
#
# Enter gender of Enbee m
#
# Enter gender of Rico m
#
# Enter gender of Payal Dev f
#
# Enter gender of Abhijeet m
#
# Enter gender of Chandra Dixit f
#
# Enter gender of Badshah m
#
# Enter gender of Akash D m
#
# Enter gender of Aditi Prabhudesai f
#
# Enter gender of Pragati Joshi f
#
# Enter gender of Maithili Panse f
#
# Enter gender of Sonal Naik f
#
# Enter gender of Rucha Soman f
#
# Enter gender of Deepti Rege f
#
# Enter gender of Deepanshi Nagar f
#
# Enter gender of Ann Fernandes m
#
# Enter gender of Dr m
#
# Enter gender of Shivika Rajesh f
#
# Enter gender of Riddhi Sampat f
#
# Enter gender of Kinjal Shah f
#
# Enter gender of Umesh Joshi m
#
# Enter gender of Vijay Dhuri m
#
# Enter gender of Mandar Pilvalkar m
#
# Enter gender of Vivek Naik m
#
# Enter gender of Rahul Chitnis m
#
# Enter gender of Saurabh Wakhare m
#
# Enter gender of Janardan Dhatrak m
#
# Enter gender of Gaurav Medatwal m
#
# Enter gender of Chaitanya Shinde f
#
# Enter gender of Abhishek Jhawar m
#
# Enter gender of Nimish Shah m
#
# Enter gender of Yash Kapoor m
#
# Enter gender of Mayukh Pareek m
#
# Enter gender of Divya Kumar f
#
# Enter gender of Chaitally Parmar f
#
# Enter gender of R Venkatraman m
#
# Enter gender of Aakanksha Sharma f
#
# Enter gender of Dee MC m
#
# Enter gender of Kaam Bhaari m
#
# Enter gender of Spitfire m
#
# Enter gender of Priyani Vani f
#
# Enter gender of Kanika Kapoor f
#
# Enter gender of Ikka m
#
# Enter gender of Neha Kakkar f
#
# Enter gender of Aanandi Joshi f
#
# Enter gender of Shreyas Puranik m
#
# Enter gender of Shipra Goyal f
#
# Enter gender of Kamaal Khan f
#
# Enter gender of Deane Sequeira f
#
# Enter gender of Shekhar Ravjiani m
#
# Enter gender of Vishal Dadlani m
#
# Enter gender of Kishore Kumar m
#
# Enter gender of Marianne f
#
# Enter gender of Mellow D m
#
# Enter gender of Navraj Hans m
#
# Enter gender of Shashi Suman m
#
# Enter gender of Goldy m
#
# Enter gender of Aditya Narayan m
#
# Enter gender of Shirley Setia f
#
# Enter gender of Abhijit Vaghani m
#
# Enter gender of Armaan Malik m
#
# Enter gender of Guru Randhawa m
#
# Enter gender of Raja Hasan m
#
# Enter gender of Yo m
#
# Enter gender of Javed Ali m
#
# Enter gender of Tushar Joshi m
#
# Enter gender of Vaishali Mhade f
#
# Enter gender of Shriram Iyer m
#
# Enter gender of Clinton Cerejo m
#
# Enter gender of Jizzy m
#
# Enter gender of Shaan m
#
# Enter gender of Subhro m
#
# Enter gender of Sunanda Sharma f
#
# Enter gender of DIVINE m
#
# Enter gender of Naezy m
#
# Enter gender of Nexus m
#
# Enter gender of Rahul Raahi m
#
# Enter gender of Emiway m
#
# Enter gender of D-cypher m
#
# Enter gender of BeatRAW m
#
# Enter gender of Big Sid m
#
# Enter gender of Shashwat Sachdev m
#
# Enter gender of Vivek Hariharan m
#
# Enter gender of Sunidhi Chauhan f
#
# Enter gender of Sukriti Kakar f
#
# Enter gender of Ena Marley f
#
# Enter gender of Santhosh Venki f
#
# Enter gender of Sachin Basrur m
#
# Enter gender of Puneeth Rudranag m
#
# Enter gender of Mohan m
#
# Enter gender of H. m
#
# Enter gender of Vijay Aurs m
#
# Enter gender of Ravi Basrur m
#
# Enter gender of Goldi m
#
# Enter gender of Tanishk Bagchi m
#
# Enter gender of Mika Singh m
#
# Enter gender of Kumar Sanu m
#
# Enter gender of Shashaa Tirupati f
#
# Enter gender of Rahat m
#
# Enter gender of Shaadab Faridi m
#
# Enter gender of Sukhwinder Singh m
#
# Enter gender of Bilal Saeed m
#
# Enter gender of Pratibha Baghel f
#
# Enter gender of Singhsta m
#
# Enter gender of Simar Kaur f
#
# Enter gender of Raghav Sachar m
#
# Enter gender of Shafqat m
#
# Enter gender of Jordan m
#
# Enter gender of Nawazuddin Siddiqui m
#
# Enter gender of Aastha Gill f
#
# Enter gender of Akanksha Bhandari f
#
# Enter gender of Ronkini Gupta f
#
# Enter gender of Neetu Bhalla m
#
# Enter gender of Divya Bhatt f
#
# Enter gender of Sachet Tandon m
#
# Enter gender of Prakriti Kakar f
#
# Enter gender of Yashita Sharma f
#
# Enter gender of Yashika Sikka f
#
# Enter gender of Rani Kaur f
#
# Enter gender of Anita Gandharva f
#
# Enter gender of Meghna Mishra f
#
# Enter gender of Vaishnavi Mishra f
#
# Enter gender of Bhanu f
#
# Enter gender of Shahid Mallya m
#
# Enter gender of Jazim Sharma m
#
# Enter gender of Amit Trivedi m
#
# Enter gender of Suhas Sawant m
#
# Enter gender of Ammy Virk f
#
# Enter gender of Sikander Kahlon m
#
# Enter gender of Amit Sharma m
#
# Enter gender of Meenal Jain f
#
# Enter gender of Babul Supriyo f
#
# Enter gender of Andrea Jeremiah f
#
# Enter gender of Shivangi Bhayana f
#
# Enter gender of Sonakshi Sinha f
#
# Enter gender of Mudassar Aziz m
#
# Enter gender of Neha Bhasin f
#
# Enter gender of Sachin Sanghvi m
#
# Enter gender of Jigar Saraiya m
#
# Enter gender of Jordi Patel m
#
# Enter gender of Disha Sharma f
#
# Enter gender of Akash Ojha m
#
# Enter gender of Rekha f
#
# Enter gender of Dharmendra m
#
# Enter gender of Shatrughan Sinha m
#
# Enter gender of Salman Khan m
#
# Enter gender of D’EVIL m
#
# Enter gender of Iulia Vantur f
#
# Enter gender of Vineet Singh m
#
# Enter gender of Arko m
#
# Enter gender of Gurinder f
#
# Enter gender of Altamash m
#
# Enter gender of Nettle m
#
# Enter gender of Aima Baig f
#
# Enter gender of Atul Gogavale m
#
# Enter gender of Shehnaz Akhtar m
#
# Enter gender of Hemant Brijwasi m
#
# Enter gender of Sahil Akhtar m
#
# Enter gender of Ehsaan Noorani m
#
# Enter gender of Ranbir Kapoor m
#
# Enter gender of Supriya Pathak f
#
# Enter gender of Poorvi Koutish f
#
# Enter gender of Veera Saxena f
#
# Enter gender of Aaroh Velankar m
#
# Enter gender of Anurag Sharma m
#
# Enter gender of Himanshu Shirlekar m
#
# Enter gender of Shubham Shirule m
#
# Enter gender of Sunny MR m
#
# Enter gender of Aditi f
#
# Enter gender of Nikita Ahuja f
#
# Enter gender of Lulia Vantur m
#
# Enter gender of Sharvi Yadav f
#
# Enter gender of Jasleen Royal f
#
# Enter gender of Fazilpuria m
#
# Enter gender of Rishi Kapoor m
#
# Enter gender of Gajendra Verma m
#
# Enter gender of Mahalakshmi Iyer f
#
# Enter gender of Jatinder Singh m
#
# Enter gender of Siddharth Basrur m
#
# Enter gender of Shruti Pathak f
#
# Enter gender of Parry G m
#
# Enter gender of Kulwinder Billa m
# Enter gender of Rajvir Jawanda m
#
# Enter gender of Sharan Maan m
#
# Enter gender of Mannat Noor m
#
# Enter gender of Arijit Singh m
#
# Enter gender of Deep Money m
#
# Enter gender of Amrita Singh f
#
# Enter gender of Khusboo Grewal f
#
# Enter gender of Sajid m
#
# Enter gender of Rochak Kohli m
#
# Enter gender of Ankit Tiwari m
#
# Enter gender of Ishers m
#
# Enter gender of Raxstar m
#
# Enter gender of Gurnam Bhullar m
#
# Enter gender of Piyush Mehroliyaa m
#
# Enter gender of Raftaar m
#
# Enter gender of Swati Sharma f
#
# Enter gender of Shail Hada m
#
# Enter gender of Mujtaba m
#
# Enter gender of Kunal Pandit m
#
# Enter gender of Farhan Sabri m
#
# Enter gender of Swaroop Khan m
#
# Enter gender of Tony Kakkar m
#
# Enter gender of Tarannum Malik m
#
# Enter gender of Roach Killa m
#
# Enter gender of Simran f
#
# Enter gender of Rajnigandha Shekhawat f
#
# Enter gender of Master m
#
# Enter gender of Sameer Uddin m
#
# Enter gender of Samira Koppikar f
#
# Enter gender of Sidharth Malhotra m
#
# Enter gender of ARJUN m
#
# Enter gender of Vickey Prasad m
#
# Enter gender of Arpita Mukherjee f
#
# Enter gender of Apeksha Dandekar f
#
# Enter gender of Amaal Mallik m
#
# Enter gender of Cuca Roseta m
#
# Enter gender of Mohit Chauhan m
#
# Enter gender of Pritam m
#
# Enter gender of Aman Trikha m
#
# Enter gender of Nooran Sisters f
#
# Enter gender of Shefali Alvares f
#
# Enter gender of Dee Ajayi m
#
# Enter gender of Mehak Malhotra f
#
# Enter gender of Millind Gaba m
#
# Enter gender of Gupz Sehra m
#
# Enter gender of Renesa Baadchi f
#
# Enter gender of Nandini Deb f
#
# Enter gender of Rahul Pandey m
#
# Enter gender of Ashwin m
#
# Enter gender of Aroh m
#
# Enter gender of Sunny m
#
# Enter gender of K Mohan m
#
# Enter gender of Sanjeev Chimmalgi m
#
# Enter gender of Ramya Behara f
#
# Enter gender of Ambili f
#
# Enter gender of Sonia Sharma f
#
# Enter gender of KD m
#
# Enter gender of Pawni Pandey f
#
# Enter gender of Juggy D m
#
# Enter gender of Shivi f
#
# Enter gender of Pardeep m

# %%
print(temp)
# Out:
# {'': 'm', 'Shalmali Kholgade': 'f', 'Gurdeep Mehendi': 'm', 'Dino James': 'm', 'Brijesh Shandilya': 'm', 'Aavrutti': 'f', 'D’Evil': 'm', 'Shah Rule': 'm', 'Dave East': 'm', 'Jubin Nautiyal': 'm', 'Saloni Thakkar': 'f', 'Akasa Singh': 'f', 'Amartya': 'f', 'Dev Arijit': 'm', 'GD 47': 'm', 'Yasser Desai': 'm', 'Asees Kaur': 'f', 'Yash Narvekar': 'm', 'Shreya Ghoshal': 'f', 'Shadab Faridi': 'm', 'Farhad Samji': 'm', 'Altamash Faridi': 'm', 'Jyotica Tangri': 'f', 'Vishal Mishra': 'm', 'Jyoti Nooran': 'f', 'Priya Saraiya': 'f', 'Jonita Gandhi': 'f', 'Sachin-Jigar': 'm', 'Nikhita Gandhi': 'f', 'Benny Dayal': 'm', 'Darshan Raval': 'm', 'Lisa Mishra': 'f', 'Antara Mitra': 'f', 'Nikhil D’Souza': 'm', 'Shilpa Rao': 'f', 'Alyssa Mendonsa': 'f', 'Shankar Mahadevan': 'm', 'Vikram Khajuria': 'm', 'Ali': 'm', 'Vikram Montrose': 'm', 'Deepali Sathe': 'f', 'Bhoomi Trivedi': 'f', 'Parampara Thakur': 'f', 'Monali Thakur': 'f', 'Manish Tipu': 'm', 'Geet Sagar': 'm', 'Sreerama Chandra': 'm', 'Amitabh Bhattacharya': 'm', 'Dev Negi': 'm', 'Amit Mishra': 'm', 'Khushboo Grewal': 'f', 'Palak Muchhal': 'f', 'Meet Bros': 'm', 'Nakash Aziz': 'm', 'Romy': 'm', 'Anand Bhaskar': 'm', 'Abhijeet Srivastava': 'm', 'Vibha Saraf': 'f', 'Himesh Reshammiya': 'm', 'Harshdeep Kaur': 'm', 'Alamgir Khan': 'm', 'Anusha Mani': 'f', 'Dhvani Bhanushali': 'f', 'Tulsi Kumar': 'm', 'B Praak': 'm', 'Protijyoti Ghosh': 'f', 'Daniel': 'm', 'Arjunna Harjaie': 'm', 'Raja Kumari': 'm', 'Ravi Mishra': 'm', 'Neeti Mohan': 'm', 'Ashok Mastie': 'm', 'Pravesh Mallick': 'm', 'Zenab': 'm', 'Jabar Abbas': 'm', 'Shiraz Uppal': 'm', 'Raktima Mukherjee': 'f', 'Mustahsan Khan': 'm', 'Zeb Bangash': 'f', 'Enbee': 'm', 'Rico': 'm', 'Payal Dev': 'f', 'Abhijeet': 'm', 'Chandra Dixit': 'f', 'Badshah': 'm', 'Akash D': 'm', 'Aditi Prabhudesai': 'f', 'Pragati Joshi': 'f', 'Maithili Panse': 'f', 'Sonal Naik': 'f', 'Rucha Soman': 'f', 'Deepti Rege': 'f', 'Deepanshi Nagar': 'f', 'Ann Fernandes': 'm', 'Dr': 'm', 'Shivika Rajesh': 'f', 'Riddhi Sampat': 'f', 'Kinjal Shah': 'f', 'Umesh Joshi': 'm', 'Vijay Dhuri': 'm', 'Mandar Pilvalkar': 'm', 'Vivek Naik': 'm', 'Rahul Chitnis': 'm', 'Saurabh Wakhare': 'm', 'Janardan Dhatrak': 'm', 'Gaurav Medatwal': 'm', 'Chaitanya Shinde': 'f', 'Abhishek Jhawar': 'm', 'Nimish Shah': 'm', 'Yash Kapoor': 'm', 'Mayukh Pareek': 'm', 'Divya Kumar': 'f', 'Chaitally Parmar': 'f', 'R Venkatraman': 'm', 'Aakanksha Sharma': 'f', 'Dee MC': 'm', 'Kaam Bhaari': 'm', 'Spitfire': 'm', 'Priyani Vani': 'f', 'Kanika Kapoor': 'f', 'Ikka': 'm', 'Neha Kakkar': 'f', 'Aanandi Joshi': 'f', 'Shreyas Puranik': 'm', 'Shipra Goyal': 'f', 'Kamaal Khan': 'f', 'Deane Sequeira': 'f', 'Shekhar Ravjiani': 'm', 'Vishal Dadlani': 'm', 'Kishore Kumar': 'm', 'Marianne': 'f', 'Mellow D': 'm', 'Navraj Hans': 'm', 'Shashi Suman': 'm', 'Goldy': 'm', 'Aditya Narayan': 'm', 'Shirley Setia': 'f', 'Abhijit Vaghani': 'm', 'Armaan Malik': 'm', 'Guru Randhawa': 'm', 'Raja Hasan': 'm', 'Yo': 'm', 'Javed Ali': 'm', 'Tushar Joshi': 'm', 'Vaishali Mhade': 'f', 'Shriram Iyer': 'm', 'Clinton Cerejo': 'm', 'Jizzy': 'm', 'Shaan': 'm', 'Subhro': 'm', 'Sunanda Sharma': 'f', 'DIVINE': 'm', 'Naezy': 'm', 'Nexus': 'm', 'Rahul Raahi': 'm', 'Emiway': 'm', 'D-cypher': 'm', 'BeatRAW': 'm', 'Big Sid': 'm', 'Shashwat Sachdev': 'm', 'Vivek Hariharan': 'm', 'Sunidhi Chauhan': 'f', 'Sukriti Kakar': 'f', 'Ena Marley': 'f', 'Santhosh Venki': 'f', 'Sachin Basrur': 'm', 'Puneeth Rudranag': 'm', 'Mohan': 'm', 'H.': 'm', 'Vijay Aurs': 'm', 'Ravi Basrur': 'm', 'Goldi': 'm', 'Tanishk Bagchi': 'm', 'Mika Singh': 'm', 'Kumar Sanu': 'm', 'Shashaa Tirupati': 'f', 'Rahat': 'm', 'Shaadab Faridi': 'm', 'Sukhwinder Singh': 'm', 'Bilal Saeed': 'm', 'Pratibha Baghel': 'f', 'Singhsta': 'm', 'Simar Kaur': 'f', 'Raghav Sachar': 'm', 'Shafqat': 'm', 'Jordan': 'm', 'Nawazuddin Siddiqui': 'm', 'Aastha Gill': 'f', 'Akanksha Bhandari': 'f', 'Ronkini Gupta': 'f', 'Neetu Bhalla': 'm', 'Divya Bhatt': 'f', 'Sachet Tandon': 'm', 'Prakriti Kakar': 'f', 'Yashita Sharma': 'f', ' ...

# %%
key = list(temp.keys())
value = list(temp.values())
df_input = []
for x,y in zip(key, value):
    df_input.append([x,y])
df = pd.DataFrame(df_input,columns = ['Name', 'Gender'])
df.to_csv("Artist_Gender_Complete.csv", index = False, header = True)

# %%
import pandas as pd

# %%
doc=[]
for i in range(data.shape[0]):
    doc.append(nltk.word_tokenize(re.sub('[^a-zA-z\s]','',data['songLyrics'][i].lower())))

# %%
doc_sent=[]
for i in range(data.shape[0]):
    doc_sent.append(re.sub('[^a-zA-z\s]','',data['songLyrics'][i].lower()).split("\n"))

# %%
# translator = Translator(service_urls=[
#       'translate.google.com',
#       'translate.google.co.kr',
#     ])

# %%
# Eng_sent=[]
# ctr=0
# for i in doc_sent:
#     cc=[]
#     for line in i:
#         if line == '' :
#             continue
        
        
#         translations = translator.translate(line,src='hi', dest='en')
#         cc.append(translations.text)
#     Eng_sent.append(cc)
#     print(ctr)
#     ctr=ctr+1

# %%
model = gensim.models.Word2Vec(doc,size=300,window=15,min_count=2,workers=10,iter=10)

# %%
model.wv.most_similar(positive=["woman"],topn=50)
# Out:
# [('bit', 0.8940521478652954),
#  ('arent', 0.8746947050094604),
#  ('some', 0.8457858562469482),
#  ('angel', 0.8383506536483765),
#  ('out', 0.8378028869628906),
#  ('stop', 0.8333471417427063),
#  ('once', 0.8319662809371948),
#  ('meaning', 0.8287794589996338),
#  ('pah', 0.827539324760437),
#  ('thats', 0.8258245587348938),
#  ('afraid', 0.8251748085021973),
#  ('down', 0.823017954826355),
#  ('boggie', 0.8217470645904541),
#  ('thinking', 0.821296215057373),
#  ('melt', 0.8212529420852661),
#  ('koothu', 0.8192253708839417),
#  ('see', 0.8138169050216675),
#  ('getting', 0.812167227268219),
#  ('put', 0.8117766976356506),
#  ('been', 0.8112106919288635),
#  ('faster', 0.8111060857772827),
#  ('core', 0.8086701035499573),
#  ('spend', 0.8085821866989136),
#  ('face', 0.8081979751586914),
#  ('seen', 0.8080255389213562),
#  ('made', 0.8066858053207397),
#  ('may', 0.8061434030532837),
#  ('mommy', 0.8060409426689148),
#  ('them', 0.8039798736572266),
#  ('dappan', 0.8034189939498901),
#  ('spin', 0.802517294883728),
#  ('charging', 0.8017741441726685),
#  ('continues', 0.8008742928504944),
#  ('way', 0.8002623319625854),
#  ('blaring', 0.7974758148193359),
#  ('botlaan', 0.796445906162262),
#  ('like', 0.7955201268196106),
#  ('round', 0.7942171096801758),
#  ('yo', 0.7937462329864502),
#  ('jhi', 0.792971670627594),
#  ('a', 0.7926472425460815),
#  ('needs', 0.7898924350738525),
#  ('shoulder', 0.7893474102020264),
#  ('nobody', 0.7892945408821106),
#  ('yolo', 0.7856432199478149),
#  ('live', 0.7851723432540894),
#  ('show', 0.7849809527397156),
#  ('voice', 0.7840218544006348),
#  ('ive', 0.7832483053207397),
#  ('drum', 0.7827928066253662)]

# %%
model.wv.similarity('halka','ladka')
# Out:
# 0.5630180288587507

# %%
def target_attribute(target_one,target_two, target_one_words, attribute_one,attribute_two, attribute_one_words, target_two_words, attribute_two_words):
    cos=[]
    s=0
    s1=[]
    s2=[]
    S=[]
    n=0
    for i in range(0, len(target_one_words)):
            c1=[]
            c2=[]
            for k in range(0, len(attribute_one_words)):
                wt = target_one_words[i][:-1]
                at1 = attribute_one_words[k][:-1]
                try:
                    cos1= model.similarity(wt, at1)
                    cos.append(cos1)
                    c1.append(cos1)
                except:
                    cos1=0
                    cos.append(cos1)
                    c1.append(cos1)
                    continue
            for k in range(0, len(attribute_two_words)):
                cos2=0
                wt = target_one_words[i][:-1]
                at2 = attribute_two_words[k][:-1]
                try:
                    cos2= model.similarity(wt, at2)
                    cos.append(cos2)
                    c2.append(cos2)
                except:
                    cos2=0
                    cos.append(cos2)
                    c2.append(cos2)
                    continue
            s1.append((np.mean(c1)-np.mean(c2)))
            S.append((np.mean(c1)-np.mean(c2)))
            n=n+1
    for i in range(0, len(target_two_words)):
            c1=[]
            c2=[]
            for k in range(0, len(attribute_one_words)):
                wt = target_two_words[i][:-1]
                at1 = attribute_one_words[k][:-1]
                try:
                    cos1= model.similarity(wt, at1)
                    cos.append(cos1)
                    c1.append(cos1)
                except:
                    cos1=0
                    cos.append(cos1)
                    c1.append(cos1)
                    continue
            for k in range(0, len(attribute_two_words)):
                cos2=0
                wt = target_two_words[i][:-1]
                at2 = attribute_two_words[k][:-1]
                try:
                    cos2= model.similarity(wt, at2)
                    cos.append(cos2)
                    c2.append(cos2)
                except:
                    cos2=0
                    cos.append(cos2)
                    c2.append(cos2)
                    continue
            s2.append((np.mean(c1)-np.mean(c2)))
            S.append((np.mean(c1)-np.mean(c2)))
    s=np.sum(s1)-np.sum(s2)
    stdev=np.std(S)
    print(target_one + ' vs ' + target_two  + ' , ' +attribute_one + ' vs ' + attribute_two +', d = ' + str(s/(stdev*n)))

# %%
# file = open( "weat.txt", "r" ) 
# file=file.read()

# %%
# tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
# raw_sentences = tokenizer.tokenize(file.lower())

# %%
# t=raw_sentences[0].split()

# %%
# raw_sentences[1].split()

# %%
# for i in range(len(raw_sentences)-30):
#     words=raw_sentences[i*4].split()
#     target_one = words[0][:-1]
#     target_one_words = words[1:]
#     words1=raw_sentences[i*4+1].split()
#     target_two = words1[0][:-1]
#     target_two_words = words1[1:]
#     words2=raw_sentences[i*4+2].split()
#     attribute_one = words2[0][:-1]
#     attribute_one_words = words2[1:]
#     words3 = raw_sentences[i*4+3].split()
#     attribute_two = words3[0][:-1]
#     attribute_two_words = words3[1:]
#     target_attribute(target_one,target_two, target_one_words, attribute_one,attribute_two, attribute_one_words, target_two_words, attribute_two_words)

# %%
target_one= 'female_names'
target_one_words=['ladki','girl','gori','lady','chokri','kudi','chhori','woman']
target_two='male_names'
target_two_words= ['ladka','munda','mundey','boy','chokra','chhora','man']
attribute_one='soft'
attribute_one_words=['nagin','naag','bholi','bhola','komalkomal','hirani','nadaan','beautiful','mastani','mastana','seedhi','seedha','sharmili','sharmila','sohni','sohna','bhali','bhala','halki','halka']
attribute_two='violent'
attribute_two_words=['kukkad','bigda','bigdi','khatra','khauf','handa','peeta','peeti','jungli']



target_attribute(target_one,target_two, target_one_words, attribute_one,attribute_two, attribute_one_words, target_two_words, attribute_two_words)
# Out:
# female_names vs male_names , soft vs violent, d = 0.8836512640956472
# /Users/shefalibansal/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   from ipykernel import kernelapp as app
# /Users/shefalibansal/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:28: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
# /Users/shefalibansal/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:46: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
# /Users/shefalibansal/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:59: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).

# %%
# translations = translator.translate(['The quick brown fox', 'jumps over', 'the lazy dog'], dest='ko')

# %%
# translations = translator.translate(['paagal hai'],src='hi', dest='en')

# %%
# for translation in translations:
#     print(translation.origin, ' -> ', translation.text)

# %%
# translations.text
